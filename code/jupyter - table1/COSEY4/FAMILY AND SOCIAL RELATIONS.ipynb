# %%
install.packages("table1")
# Out:
# Installing package into ‘/home/jupyter/.R/library’
# (as ‘lib’ is unspecified)

# %%
library(bigrquery)
library(knitr)
library(tidyverse)
library(ggplot2)
library("table1")
library("IRdisplay")
library(grid)
library(gridExtra)
bq_auth()
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.2     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘table1’
#
#
# The following objects are masked from ‘package:base’:
#
#     units, units<-
#
#
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %%
data <-bq_dataset_query(query="
SELECT *

 FROM `yhcr-prd-phm-bia-core.CB_1935_AK.src_bmbc_HVDatafINAL`"
                       ,x="yhcr-prd-phm-bia-core.CB_1935_AK")

HVDatafINAL <- bq_table_download(data)

# %%
 PersonalSocial<-unique(filter(HVDatafINAL,ASQ == "ASQ-3 24 month questionnaire - communication score"))

# %%
display_jupyter <- function(x) {
  css <- system.file("table1_defaults_1.0/table1_defaults.css", package="table1")
  css <- paste(readLines(css), collapse="\n")
  x <- htmltools::tagList(htmltools::tags$style(css), htmltools::tags$div(class="Rtable1", x))
  IRdisplay::display_html(as.character(x))
}

# %%
label(PersonalSocial$event_year)      <- "Year of Measure"
label(PersonalSocial$IMD)      <- "IMD"
label(PersonalSocial$gender_source_value)      <- "Gender"
label( PersonalSocial$ethnic_group)      <- "Ethnic Group"

# %%
x1 <-table1(~ PersonalSocial$event_year +  PersonalSocial$gender_source_value + PersonalSocial$ethnic_group+ PersonalSocial$IMD|PersonalSocial$result,data=PersonalSocial
          ,justify=c("left", "left", rep("center", 5)),format_number = TRUE
          ,caption = "COS-EY 4: Social environment-4.1 Family & social relationships"
    
         )

# %%
 display_jupyter(x1)
# Out:
# <style>/* Default */
# .Rtable1 table, table.Rtable1 {
#     font-family: "Arial", Arial, sans-serif;
#     font-size: 10pt;
#     border-collapse: collapse;
#     padding: 0px;
#     margin: 0px;
#     /* margin-bottom: 10pt; */
# }
# .Rtable1 td {
#     white-space:nowrap;
# }
# .Rtable1 th, .Rtable1 td {
#     border: 0;
#     text-align: center;
#     padding: 0.5ex 1.5ex;
#     margin: 0px;
# }
# .Rtable1 thead&gt;tr:first-child&gt;th {
#     border-top: 2pt solid black;
# }
# .Rtable1 thead&gt;tr:last-child&gt;th {
#     border-bottom: 1pt solid black;
# }
# .Rtable1 tbody&gt;tr:last-child&gt;td {
#     border-bottom: 2pt solid black;
# }
# .Rtable1 th.grouplabel {
#     padding-left: 0;
#     padding-right: 0;
# }
# .Rtable1 th.grouplabel&gt;div {
#     margin-left: 1.5ex;
#     margin-right: 1.5ex;
#     border-bottom: 1pt solid black;
# }
# .Rtable1 th.grouplabel:last-child&gt;div {
#     margin-right: 0;
# }
# .Rtable1 .rowlabel {
#     text-align: left;
#     padding-left: 2.5ex;
# }
# .Rtable1 .firstrow.rowlabel {
#     padding-left: 0.5ex;
#     font-weight: bold;
# }
#
# /* Zebra stripes */
# .Rtable1-zebra tbody tr:nth-child(odd) {
#     background-color: #eee;
# }
#
# /* Times font */
# table.Rtable1-times {
#     font-family: "Times New Roman", Times, serif;
# }
#
# /* Shade style */
# .Rtable1-shade th {
#     background-color: #ccc;
# }
#
# /* Grid style */
# .Rtable1-grid th, .Rtable1-grid td {
#     border-left: 1pt solid black;
#     border-right: 1pt solid black;
# }
# .Rtable1-grid thead&gt;tr:first-child&gt;th {
#     border-top: 1pt solid black;
# }
# .Rtable1-grid thead&gt;tr:last-child&gt;th {
#     border-bottom: 1pt solid black;
# }
# .Rtable1-grid tbody&gt;tr:last-child&gt;td {
#     border-bottom: 1pt solid black;
# }
# .Rtable1-grid .firstrow, .Rtable1-grid .firstrow ~ td {
#     border-top: 1pt solid black;
# }
# .Rtable1-grid th.grouplabel&gt;div {
#     margin-left: 0;
#     margin-right: 0;
#     border-bottom: 0;
# }
#
# /* Center style */
# .Rtable1-center td.rowlabel, .Rtable1-center td.firstrow.rowlabel {
#     font-weight: bold;
#     text-align: center;
#     padding: 0.5ex 1.5ex;
# }
#
# /* Footnote */
# .Rtable1 .Rtable1-footnote {
#     font-size: smaller;
#     padding: 0px;
#     margin: 0px;
#     text-align: left;
#     white-space: normal;
# }
# </style>
# <div class="Rtable1"><table class="Rtable1"><caption>COS-EY 4: Social environment-4.1 Family & social relationships</caption>
#
# <thead>
# <tr>
# <th class='rowlabel firstrow lastrow'></th>
# <th class='firstrow lastrow'><span class='stratlabel'>Child devlopement on schedule<br><span class='stratn'>(N=3360)</span></span></th>
# <th class='firstrow lastrow'><span class='stratlabel'>Further assesment needed<br><span class='stratn'>(N=445)</span></span></th>
# <th class='firstrow lastrow'><span class='stratlabel'>Provide learning activities and monitor<br><span class='stratn'>(N=416)</span></span></th>
# <th class='firstrow lastrow'><span class='stratlabel'>Overall<br><span class='stratn'>(N=4221)</span></span></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class='rowlabel firstrow'>Year of Measure</td>
# <td class='firstrow'></td>
# <td class='firstrow'></td>
# <td class='firstrow'></td>
# <td class='firstrow'></td>
# </tr>
# <tr>
# <td class='rowlabel'>2015</td>
# <td>202 (6.0%)</td>
# <td>14 (3.1%)</td>
# <td>22 (5.3%)</td>
# <td>238 (5.6%)</td>
# </tr>
# <tr>
# <td class='rowlabel'>2016</td>
# <td>625 (18.6%)</td>
# <td>59 (13.3%)</td>
# <td>72 (17.3%)</td>
# <td>756 (17.9%)</td>
# </tr>
# <tr>
# <td class='rowlabel'>2017</td>
# <td>792 (23.6%)</td>
# <td>96 (21.6%)</td>
# <td>91 (21.9%)</td>
# <td>979 (23.2%)</td>
# </tr>
# <tr>
# <td class='rowlabel'>2018</td>
# <td>864 (25.7%)</td>
# <td>117 (26.3%)</td>
# <td>111 (26.7%)</td>
# <td>1092 (25.9%)</td>
# </tr>
# <tr>
# <td class='rowlabel'>2019</td>
# <td>538 (16.0%)</td>
# <td>64 (14.4%)</td>
# <td>71 (17.1%)</td>
# <td>673 (15.9%)</td>
# </tr>
# <tr>
# <td class='rowlabel'>2020</td>
# <td>139 (4.1%)</td>
# <td>22 (4.9%)</td>
# <td>16 (3.8%)</td>
# <td>177 (4.2%)</td>
# </tr>
# <tr>
# <td class='rowlabel'>2021</td>
# <td>89 (2.6%)</td>
# <td>35 (7.9%)</td>
# <td>18 (4.3%)</td>
# <td>142 (3.4%)</td>
# </tr>
# <tr>
# <td class='rowlabel'>2022</td>
# <td>73 (2.2%)</td>
# <td>25 (5.6%)</td>
# <td>11 (2.6%)</td>
# <td>109 (2.6%)</td>
# </tr>
# <tr>
# <td class='rowlabel lastrow'>2023</td>
# <td class='lastrow'>38 (1.1%)</td>
# <td class='lastrow'>13 (2.9%)</td>
# <td class='lastrow'>4 (1.0%)</td>
# <td class='lastrow'>55 (1.3%)</td>
# </tr>
# <tr>
# <td class='rowlabel firstrow'>Gender</td>
# <td class='firstrow'></td>
# <td class='firstrow'></td>
# <td class='firstrow'></td>
# <td class='firstrow'></td>
)</td>
# </tr>
# <tr>
# <td class='rowlabel'>7</td>
# <td>187 (5.6%)</td>
# <td>7 (1.6%)</td>
# <td>15 (3.6%)</td>
# <td>209 (5.0%)</td>
# </tr>
# <tr>
# <td class='rowlabel'>8</td>
# <td>155 (4.6%)</td>
# <td>15 (3.4%)</td>
# <td>14 (3.4%)</td>
# <td>184 (4.4%)</td>
# </tr>
# <tr>
# <td class='rowlabel lastrow'>9</td>
# <td class='lastrow'>65 (1.9%)</td>
# <td class='lastrow'>2 (0.4%)</td>
# <td class='lastrow'>4 (1.0%)</td>
# <td class='lastrow'>71 (1.7%)</td>
# </tr>
# </tbody>
# </table>
# </div>

# %%
OverallTrend1 <- PersonalSocial %>% select(1,8,7)

PersonalSocial1 <- OverallTrend1 %>%
  group_by(event_year,result) 

PS1<- PersonalSocial1 %>% count(result,event_year)


PS1<- group_by(PS1, event_year) %>% mutate(percent = (n/sum(n))*100)


#PS1<-unique(filter(PS1,result =="Child devlopement on schedule" ))

PS1<- group_by(PS1, event_year) %>% mutate(percent = (n/sum(n))*100)
PS1<-unique(filter(PS1,result =="Child devlopement on schedule" ))
#PS1<-unique(filter(PS1,ALevelOutcome == "1. 3 Or More Alevels at A*-B"))

# %%
OVERALL<- ggplot(PS1 , aes(x = event_year, y = percent,group = 1)) +
#scale_y_continuous( limits=c(0,1))+
  geom_line() +
  geom_point() +
   ggtitle(expression(atop("Children reaching 'on scheduale - at 2-2.5 year old health visit"))) +


labs(
       x = "Event Year",
       y = "Percentage of children per year") +
scale_y_continuous(labels = function(x) paste0(x, "%"))+
               theme(panel.border = element_blank(),# panel.grid.major = element_blank(),
#panel.grid.minor = element_blank(), 
      axis.line = element_line(colour = "black"),axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))+
geom_text(aes(label = round(percent,0)), hjust = 0.5,  vjust = -1) +
                   #+
  theme_minimal()
# Out:
# plot without title

# %%
PersonalSocial
# Out:
#      person_id ethnic_group                 gender_source_value
# 1    13111453  Unknown                      Male
# 2    13537794  Asian or Asian British       Male
# 3    12613869  Asian or Asian British       Male
# 4    12590423  Asian or Asian British       Male
# 5    12935918  Other ethnic group           Male
# 6    13705266  Asian or Asian British       Female
# 7    12534858  Asian or Asian British       Female
# 8    13582476  Asian or Asian British       Male
# 9    13580057  White                        Male
# 10   13281082  Asian or Asian British       Female
# 11   13586166  Asian or Asian British       Female
# 12   12720379  Asian or Asian British       Male
# 13   13018492  Asian or Asian British       Female
# 14   12934963  White                        Female
# 15   13302371  Asian or Asian British       Male
# 16   13615883  White                        Female
# 17   13406746  Mixed multiple ethnic groups Male
# 18   12678567  Asian or Asian British       Male
# 19   13501120  Asian or Asian British       Female
# 20   12479104  White                        Male
# 21   13540968  White                        Male
# 22   12796351  White                        Male
# 23   13504508  White                        Female
# 24   13199618  Asian or Asian British       Female
# 25   13189334  White                        Male
# 26   12915506  White                        Male
# 27   13312150  White                        Male
# 28   13675461  White                        Male
# 29   13190970  White                        Male
# 30   13644433  Asian or Asian British       Female
# ⋮    ⋮         ⋮                            ⋮
# 8117 12388708  White                        Female
# 8118 12410574  White                        Male
# 8119 13372960  Asian or Asian British       Male
# 8120 12462296  White                        Female
# 8121 12473812  Asian or Asian British       Female
# 8122   636947  White                        Female
# 8123 12430033  Mixed multiple ethnic groups Male
# 8124 12768309  Asian or Asian British       Female
# 8125 13682376  Asian or Asian British       Female
# 8124 ASQ-3 24 month questionnaire - personal-social score 60           2
# 8125 ASQ-3 24 month questionnaire - personal-social score 60           1
# 8126 ASQ-3 24 month questionnaire - personal-social score 60           1
# 8127 ASQ-3 24 month questionnaire - personal-social score 60           3
# 8128 ASQ-3 24 month questionnaire - personal-social score 60           1
# 8129 ASQ-3 24 month questionnaire - personal-social score 60           1
# 8130 ASQ-3 24 month questionnaire - personal-social score 60           6
# 8131 ASQ-3 24 month questionnaire - personal-social score 60           1
# 8132 ASQ-3 24 month questionnaire - personal-social score 60           3
# 8133 ASQ-3 24 month questionnaire - personal-social score 60           1
# 8134 ASQ-3 24 month questionnaire - personal-social score 60           4
# 8135 ASQ-3 24 month questionnaire - personal-social score 60           2
# 8136 ASQ-3 24 month questionnaire - personal-social score 60           5
# 8137 ASQ-3 24 month questionnaire - personal-social score 60           4
# 8138 ASQ-3 24 month questionnaire - personal-social score 60           7
# 8139 ASQ-3 24 month questionnaire - personal-social score 60           1
# 8140 ASQ-3 24 month questionnaire - personal-social score 60           6
# 8141 ASQ-3 24 month questionnaire - personal-social score 60           3
# 8142 ASQ-3 24 month questionnaire - personal-social score 60           1
# 8143 ASQ-3 24 month questionnaire - personal-social score 60           6
# 8144 ASQ-3 24 month questionnaire - personal-social score 60           1
# 8145 ASQ-3 24 month questionnaire - personal-social score 60           1
# 8146 ASQ-3 24 month questionnaire - personal-social score 60           4
#      event_year result
# 1    2015       Further assesment needed
# 2    2019       Provide learning activities and monitor
# 3    2016       Child devlopement on schedule
# 4    2020       Child devlopement on schedule
# 5    2016       Child devlopement on schedule
# 6    2018       Provide learning activities and monitor
# 7    2018       Provide learning activities and monitor
# 8    2016       Provide learning activities and monitor
# 9    2016       Child devlopement on schedule
# 10   2022       Provide learning activities and monitor
# 11   2016       Provide learning activities and monitor
# 12   2015       Child devlopement on schedule
# 13   2018       Provide learning activities and monitor
# 14   2018       Provide learning activities and monitor
# 15   2017       Child devlopement on schedule
# 16   2015       Provide learning activities and monitor
# 17   2019       Child devlopement on schedule
# 18   2016       Child devlopement on schedule
# 19   2018       Child devlopement on schedule
# 20   2018       Child devlopement on schedule
# 21   2018       Provide learning activities and monitor
# 22   2017       Child devlopement on schedule
# 23   2016       Further assesment needed
# 24   2018       Child devlopement on schedule
# 25   2019       Child devlopement on schedule
# 26   2015       Provide learning activities and monitor
# 27   2015       Child devlopement on schedule
# 28   2018       Child devlopement on schedule
# 29   2019       Child devlopement on schedule
# 30   2015       Provide learning activities and monitor
# ⋮    ⋮          ⋮
# 8117 2019       Child devlopement on schedule
# 8118 2017       Child devlopement on schedule
# 8119 2018       Child devlopement on schedule
# 8120 2017       Child devlopement on schedule
# 8121 2018       Child devlopement on schedule
# 8122 2016       Child devlopement on schedule
# 8123 2018       Child devlopement on schedule
# 8124 2016       Child devlopement on schedule
# 8125 2018       Child devlopement on schedule
# 8126 2019       Child devlopement on schedule
# 8127 2018       Child devlopement on schedule
# 8128 2019       Child devlopement on schedule
# 8129 2016       Child devlopement on schedule
# 8130 2016       Child devlopement on schedule
# 8131 2018       Child devlopement on schedule
# 8132 2018       Child devlopement on schedule
# 8133 2015       Child devlopement on schedule
# 8134 2016       Child devlopement on schedule
# 8135 2018       Child devlopement on schedule
# 8136 2016       Child devlopement on schedule
# 8137 2017       Child devlopement on schedule
# 8138 2018       Child devlopement on schedule
# 8139 2016       Child devlopement on schedule
# 8140 2019       Child devlopement on schedule
# 8141 2016       Child devlopement on schedule
# 8142 2021       Child devlopement on schedule
# 8143 2019       Child devlopement on schedule
# 8144 2016       Child devlopement on schedule
# 8145 2017       Child devlopement on schedule
# 8146 2018       Child devlopement on schedule

# %%
OverallTrend1 <- PersonalSocial %>% select(1,2,8,7)

PersonalSocial1 <- OverallTrend1 %>%
  group_by(event_year,result,ethnic_group) 

PS1<- PersonalSocial1 %>% count(result,event_year,ethnic_group)


PS1<- group_by(PS1, event_year,ethnic_group) %>% mutate(percent = (n/sum(n))*100)


#PS1<-unique(filter(PS1,result =="Child devlopement on schedule" ))

PS1<- group_by(PS1, event_year,ethnic_group) %>% mutate(percent = (n/sum(n))*100)
PS1<-unique(filter(PS1,result =="Child devlopement on schedule" ))
#PS1<-unique(filter(PS1,ALevelOutcome == "1. 3 Or More Alevels at A*-B"))

# %%
PS1
# Out:
#    event_year result
# 1  2015       Child devlopement on schedule
# 2  2015       Child devlopement on schedule
# 3  2015       Child devlopement on schedule
# 4  2015       Child devlopement on schedule
# 5  2015       Child devlopement on schedule
# 6  2015       Child devlopement on schedule
# 7  2016       Child devlopement on schedule
# 8  2016       Child devlopement on schedule
# 9  2016       Child devlopement on schedule
# 10 2016       Child devlopement on schedule
# 11 2016       Child devlopement on schedule
# 12 2016       Child devlopement on schedule
# 13 2017       Child devlopement on schedule
# 14 2017       Child devlopement on schedule
# 15 2017       Child devlopement on schedule
# 16 2017       Child devlopement on schedule
# 17 2017       Child devlopement on schedule
# 18 2017       Child devlopement on schedule
# 19 2018       Child devlopement on schedule
# 20 2018       Child devlopement on schedule
# 21 2018       Child devlopement on schedule
# 22 2018       Child devlopement on schedule
# 23 2018       Child devlopement on schedule
# 24 2018       Child devlopement on schedule
# 25 2019       Child devlopement on schedule
# 26 2019       Child devlopement on schedule
# 27 2019       Child devlopement on schedule
# 28 2019       Child devlopement on schedule
# 29 2019       Child devlopement on schedule
# 30 2019       Child devlopement on schedule
# 31 2020       Child devlopement on schedule
# 32 2020       Child devlopement on schedule
# 33 2020       Child devlopement on schedule
# 34 2020       Child devlopement on schedule
# 35 2020       Child devlopement on schedule
# 36 2020       Child devlopement on schedule
# 37 2021       Child devlopement on schedule
# 38 2021       Child devlopement on schedule
# 39 2021       Child devlopement on schedule
# 40 2021       Child devlopement on schedule
# 41 2021       Child devlopement on schedule
# 42 2021       Child devlopement on schedule
# 43 2022       Child devlopement on schedule
# 44 2022       Child devlopement on schedule
# 45 2022       Child devlopement on schedule
# 46 2022       Child devlopement on schedule
# 47 2022       Child devlopement on schedule
# 48 2022       Child devlopement on schedule
# 49 2023       Child devlopement on schedule
# 50 2023       Child devlopement on schedule
# 51 2023       Child devlopement on schedule
# 52 2023       Child devlopement on schedule
# 53 2023       Child devlopement on schedule
# 54 2023       Child devlopement on schedule
#    ethnic_group                                   n   percent
# 1  Asian or Asian British                         137  88.96104
# 2  Black or African or Caribbean or Black British   5  83.33333
# 3  Mixed multiple ethnic groups                    25  83.33333
# 4  Other ethnic group                               3 100.00000
# 5  Unknown                                         26  81.25000
# 6  White                                          200  84.38819
# 7  Asian or Asian British                         488  83.56164
# 8  Black or African or Caribbean or Black British  21  91.30435
# 9  Mixed multiple ethnic groups                    71  89.87342
# 10 Other ethnic group                              12  75.00000
# 11 Unknown                                         69  82.14286
# 12 White                                          648  87.09677
# 13 Asian or Asian British                         626  85.17007
# 14 Black or African or Caribbean or Black British  16  69.56522
# 15 Mixed multiple ethnic groups                    57  74.02597
# 16 Other ethnic group                              21 100.00000
# 17 Unknown                                         77  81.05263
# 18 White                                          747  87.77908
# 19 Asian or Asian British                         841  83.10277
# 20 Black or African or Caribbean or Black British  36  85.71429
# 21 Mixed multiple ethnic groups                    91  91.00000
# 22 Other ethnic group                              28  84.84848
# 23 Unknown                                         47  83.92857
# 24 White                                          836  87.35632
# 25 Asian or Asian British                         503  80.86817
# 26 Black or African or Caribbean or Black British  13  81.25000
# 27 Mixed multiple ethnic groups                    48  88.88889
# 28 Other ethnic group                              18  90.00000
# 29 Unknown                                         25  83.33333
# 30 White                                          503  86.57487
# 31 Asian or Asian British                          97  82.20339
# 32 Black or African or Caribbean or Black British   1  50.00000
# 33 Mixed multiple ethnic groups                    20  86.95652
# 34 Other ethnic group                               6  85.71429
# 35 Unknown                                          5  83.33333
# 36 White                                          142  82.08092
# 37 Asian or Asian British                          54  76.05634
# 38 Black or African or Caribbean or Black British   5  62.50000
# 39 Mixed multiple ethnic groups                     8  57.14286
# 40 Other ethnic group                               5  83.33333
# 41 Unknown                                          5  62.50000
# 42 White                                           81  71.68142
# 43 Asian or Asian British                          45  60.81081
# 44 Black or African or Caribbean or Black British   3 100.00000
# 45 Mixed multiple ethnic groups                    11  68.75000
# 46 Other ethnic group                               1  50.00000
# 47 Unknown                                          3  60.00000
# 48 White                                           52  59.09091
# 49 Asian or Asian British                          26  68.42105
# 50 Black or African or Caribbean or Black British   3  37.50000
# 51 Mixed multiple ethnic groups                     1  25.00000
# 52 Other ethnic group                               2  66.66667
# 53 Unknown                                          4  57.14286
# 54 White                                           17  53.12500

# %%
#ethnicity<-
ggplot(PS1 , aes(x = event_year, y = percent,group = ethnic_group,color = ethnic_group)) +
#scale_y_continuous( limits=c(0,1))+
  geom_line() +
  geom_point() +
   ggtitle(expression(atop("Children reaching 'on scheduale - at 2-2.5 year old health visit"))) +


labs(
       x = "Event Year",
       y = "Percentage of children per year") +
scale_y_continuous(labels = function(x) paste0(x, "%"))+
               theme(panel.border = element_blank(),# panel.grid.major = element_blank(),
#panel.grid.minor = element_blank(), 
      axis.line = element_line(colour = "black"),axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))+
geom_text(aes(label = round(percent,0)), hjust = 1,  vjust = -1) +
                   #+
  theme_minimal()
# Out:
# plot without title
